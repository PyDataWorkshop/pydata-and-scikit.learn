# %% [markdown]
# ### Introduction
#  - text

# %%
A=9;
B=8;
A+B
# Out:
# 17

# %%
import pandas as pd
import numpy as np
# import seaborn as sb

# %%
iris = pd.read_csv("iris.csv")

# %% [markdown]
# ### Iris Data Set
# First Column is case number - IGNORE
#
# - 4 numeric variables
# - 1 categorical variable
#
# Notice - ROW NUMBER FOR EACH CASE
# Python is "Zero Indexed" (Other languages such as R are "1-Indexed"

# %%
iris.head(10)
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa
# 5           6           5.4          3.9           1.7          0.4  setosa
# 6           7           4.6          3.4           1.4          0.3  setosa
# 7           8           5.0          3.4           1.5          0.2  setosa
# 8           9           4.4          2.9           1.4          0.2  setosa
# 9          10           4.9          3.1           1.5          0.1  setosa

# %%
iris.describe()
# Out:
#        Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    75.500000      5.843333     3.057333      3.758000     1.199333
# std     43.445368      0.828066     0.435866      1.765298     0.762238
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000

# %%
### Something Like this
### iris.rename(columns={"Unnamed": "Case"},inplace=True)

# %%
iris.head(2)
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa

# %%
byspecies = iris.groupby('Species')

# %%
byspecies['Sepal.Width'].describe()
# Out:
# Species
# setosa      count    50.000000
#             mean      3.428000
#             std       0.379064
#             min       2.300000
#             25%       3.200000
#             50%       3.400000
#             75%       3.675000
#             max       4.400000
# versicolor  count    50.000000
#             mean      2.770000
#             std       0.313798
#             min       2.000000
#             25%       2.525000
#             50%       2.800000
#             75%       3.000000
#             max       3.400000
# virginica   count    50.000000
#             mean      2.974000
#             std       0.322497
#             min       2.200000
#             25%       2.800000
#             50%       3.000000
#             75%       3.175000
#             max       3.800000
# dtype: float64
